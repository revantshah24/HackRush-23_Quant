# %%
import yfinance as yf
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
msft = yf.Ticker("MSFT")
hist = msft.history(period='100d')
hist.head()
# Out:
#                   Open        High         Low       Close    Volume  \
# Date
# 2022-04-19  278.140432  284.900315  277.174735  284.034149  22297700
# 2022-04-20  288.115967  288.414655  284.103849  285.089447  22906700
# 2022-04-21  287.299602  291.998661  278.817415  279.564087  29454600
# 2022-04-22  280.430231  281.943506  272.167068  272.814178  29405800
# 2022-04-25  272.077460  279.862741  269.568622  279.474487  35678900
#
#             Dividends  Stock Splits
# Date
# 2022-04-19        0.0             0
# 2022-04-20        0.0             0
# 2022-04-21        0.0             0
# 2022-04-22        0.0             0
# 2022-04-25        0.0             0

# %%
open_msft = hist.Open
close_msft = hist.Close
high_msft = hist.High
low_msft = hist.Low

# %%
plt.plot(open_msft, label='Open')
plt.plot(close_msft, label='Close')
